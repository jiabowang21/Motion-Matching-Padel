# %% [markdown]
# ## Libraries needed

# %%
# Instalar NumPy
# !python -m pip install numpy

# Instalar scikit-learn (para KD-tree)
# !python -m pip install scikit-learn

# Instalar pymotion (para generar CSV desde BVH)
# !python -m pip install upc-pymotion

# !python -m pip install upc-pymotion matplotlib

pip install upc-pymotion[viewer]

# %%
import os
import numpy as np
from math import cos, radians
from sklearn.neighbors import KDTree
from pymotion.io.bvh import BVH
import matplotlib.pyplot as plt

# =========================
# Parameters
# =========================

STEP = 10                          # Process every N frames
ANGLE_THRESHOLD_DEG = 30           # Direction change threshold
ANGLE_THRESHOLD_COS = cos(radians(ANGLE_THRESHOLD_DEG))
MIN_DISPLACEMENT = 1e-3            # Ignore tiny movements
GROUND_AXES = (0, 2)               # x, z

# =========================
# Utilities (Funciones)
# =========================

def cosine_between(v1, v2):
    """
    Compute the cosine of the angle between two vectors.
    Useful to detect sudden changes in motion direction.
    """
    return np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))


def load_root_positions_from_bvh(bvh_path):
    """
    Load the global root joint positions from a BVH file.

    Parameters:
        bvh_path (str): Path to the BVH file.

    Returns:
        np.ndarray: Array of shape (num_frames, 3) containing
                    global root positions (x, y, z) per frame.
    """
    bvh = BVH()
    bvh.load(bvh_path)
    _, local_positions, _, _, _, _ = bvh.get_data()
    global_positions = local_positions[:, 0, :]  # root joint
    return global_positions

# =========================
# KD-tree Data Construction
# =========================

def build_motion_dataset_from_bvhs(bvh_files):
    """
    Build a KD-tree dataset from multiple BVH files combined.

    Parameters:
        bvh_files (list of str): List of BVH file paths.

    Returns:
        X (np.ndarray): KD-tree points of shape (N, 3) [dx, dz, time].
        metadata (list of tuples): (file_id, start_frame) for each point.

    Notes:
        - Handles BVH files with any number of frames safely.
        - Projects motion onto the ground plane (x, z).
        - Splits motion segments if displacement is too small or direction changes sharply.
    """
    entries = []

    for file_id, bvh_file in enumerate(bvh_files):
        global_positions = load_root_positions_from_bvh(bvh_file)
        # Ensure it's a proper numpy array of shape (num_frames, 3)
        global_positions = np.array(global_positions, dtype=float)
        num_frames = len(global_positions)

        if num_frames < 2:
            # Skip BVHs with too few frames
            continue

        root_pos = global_positions[0]
        prev_disp = None
        offset = np.array([0.0, 0.0])
        current_start_frame = 0

        for f in range(STEP, num_frames, STEP):
            new_root_pos = global_positions[f]

            # Compute displacement in X-Z plane
            disp = np.array([
                new_root_pos[0] - root_pos[0],
                new_root_pos[2] - root_pos[2]
            ])
            root_pos = new_root_pos
            disp_len = np.linalg.norm(disp)

            # Reset segment if displacement is too small
            if disp_len < MIN_DISPLACEMENT:
                current_start_frame = f
                offset[:] = 0.0
                prev_disp = None
                continue

            # Reset segment if direction changes sharply
            if prev_disp is not None:
                cos_angle = cosine_between(disp, prev_disp)
                if cos_angle < ANGLE_THRESHOLD_COS:
                    current_start_frame = f
                    offset[:] = 0.0
                    prev_disp = None
                    continue

            # Accumulate displacement and elapsed time
            offset += disp
            time = f - current_start_frame

            # Save KD-tree point and metadata
            entries.append([
                offset[0],          # displacement_x
                offset[1],          # displacement_z
                time,               # elapsed time
                file_id,            # which BVH file
                current_start_frame # starting frame of segment
            ])
            prev_disp = disp

    # Split into KD-tree points and metadata
    X = np.array([[e[0], e[1], e[2]] for e in entries])
    metadata = [(e[3], e[4]) for e in entries]

    return X, metadata

# =========================
# KD-tree Wrapper
# =========================

class MotionKDTree:
    """
    Wrapper for a KD-tree that stores motion segments and allows
    querying for the best matching motion sequence.
    """

    def __init__(self, X, metadata):
        """
        Initialize KD-tree with motion data.
        """
        self.tree = KDTree(X)
        self.metadata = metadata

    def query(self, displacement_x, displacement_z, time, k=5):
        """
        Query the KD-tree for the k closest motion segments.

        Returns:
            list of dicts: Each dict contains:
                - file_id: index of BVH file
                - start_frame: starting frame of the motion segment
                - distance: KD-tree distance to the query point
        """
        query_point = np.array([[displacement_x, displacement_z, time]])
        dist, idx = self.tree.query(query_point, k=k)
        results = []
        for i, d in zip(idx[0], dist[0]):
            file_id, start_frame = self.metadata[i]
            results.append({"file_id": file_id, "start_frame": start_frame, "distance": d})
        return results

# %%
# =========================
# Example Usage
# =========================

if __name__ == "__main__":

    # -------------------------
    # 1. Load BVH files
    # -------------------------
    bvh_folder = r"C:\Users\jiabo\Desktop\TFM\BBDD-professional\BVH processed"
    bvh_files = [os.path.join(bvh_folder, f) for f in os.listdir(bvh_folder) if f.endswith(".bvh")]

    print(f"Found {len(bvh_files)} BVH files")

    # -------------------------
    # 2. Build KD-tree dataset
    # -------------------------
    X, metadata = build_motion_dataset_from_bvhs(bvh_files)
    motion_tree = MotionKDTree(X, metadata)
    print(f"KD-tree built with {len(X)} points")

    # -------------------------
    # 3. Example query
    # -------------------------
    dx, dz, t = 1.0, 0.5, 20
    results = motion_tree.query(dx, dz, t, k=3)
    print("Query results:")
    for r in results:
        file_name = os.path.basename(bvh_files[r['file_id']])
        print(f"BVH: {file_name}, start_frame: {r['start_frame']}, distance: {r['distance']:.4f}")

    # -------------------------
    # 4. Plot trajectory of the first BVH
    # -------------------------
    global_positions = load_root_positions_from_bvh(bvh_files[0])
    x = global_positions[:, 0]
    z = global_positions[:, 2]

    plt.figure(figsize=(6, 6))
    plt.plot(x, z, '-o', markersize=3)
    plt.xlabel("X Position")
    plt.ylabel("Z Position")
    plt.title(f"Root joint trajectory: {os.path.basename(bvh_files[0])}")
    plt.grid(True)
    plt.axis("equal")
    plt.show()
# Out:
# Found 20 BVH files
# KD-tree built with 14960 points
# Query results:
# BVH: Padel6Junio2025-006.bvh, start_frame: 3950, distance: 0.0578
# BVH: Padel6Junio2025-010.bvh, start_frame: 3780, distance: 0.0736
# BVH: Padel6Junio2025-005.bvh, start_frame: 4590, distance: 0.1000

# %%
from pymotion.render.viewer import Viewer
from pymotion.io.bvh import BVH
from pymotion.ops.skeleton import fk
import numpy as np

# -------------------------
# 1. Seleccionamos el resultado de la query
# -------------------------
result = results[0]  # primer resultado de la query
file_id = result['file_id']
start_frame = result['start_frame']
segment_length = 20  # número de frames a resaltar

bvh_file = bvh_files[file_id]

# -------------------------
# 2. Carga del BVH
# -------------------------
bvh = BVH()
bvh.load(bvh_file)

local_rotations, local_positions, parents, offsets, _, _ = bvh.get_data()
global_positions = local_positions[:, 0, :]  # solo root joint
pos, rotmats = fk(local_rotations, global_positions, offsets, parents)

num_frames = pos.shape[0]

# -------------------------
# 3. Preparar visor 3D
# -------------------------
viewer = Viewer(use_reloader=True, xy_size=5)
viewer.add_floor()

# -------------------------
# 4. Añadir esqueleto completo
# -------------------------
viewer.add_skeleton(pos, parents, color=(0.7, 0.7, 0.7))  # gris para todo

# -------------------------
# 5. Resaltar segmento de la query
# -------------------------
# Tomamos los frames del segmento
end_frame = min(start_frame + segment_length, num_frames)
segment_pos = pos[start_frame:end_frame]

# Crear un pequeño "esqueleto" temporal para el segmento
# Lo dibujamos en rojo para destacarlo
viewer.add_skeleton(segment_pos, parents, color=(1.0, 0.0, 0.0))  # rojo

# -------------------------
# 6. Ejecutar el visor
# -------------------------
viewer.run()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from pymotion.render.viewer import Viewer
#       2 from pymotion.io.bvh import BVH
#       3 from pymotion.ops.skeleton import fk
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pymotion\render\viewer.py:26
#      22         raise ImportError(message)
#      25 # Call the check when the subpackage is imported
# ---> 26 _check_dependencies()
#      29 import json
#      30 from typing import List, Union
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pymotion\render\viewer.py:22, in _check_dependencies()
#      15 if missing_packages:
#      16     message = (
#      17         f"The 'pymotion.render.viewer' subpackage requires the following packages to be installed: "
#      18         f"{', '.join(missing_packages)} \n"
#      19         f"Please install them using pip: \n"
#      20         f"pip install upc-pymotion[viewer] \n"
#      21     )
# ---> 22     raise ImportError(message)
#
# ImportError: The 'pymotion.render.viewer' subpackage requires the following packages to be installed: plotly, dash, dash_bootstrap_components
# Please install them using pip:
# pip install upc-pymotion[viewer]

# %%
pip install upc-pymotion[viewer]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: upc-pymotion[viewer] in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (0.2.3)
# Requirement already satisfied: numpy>=1.20.0 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from upc-pymotion[viewer]) (2.4.2)
# Collecting dash (from upc-pymotion[viewer])
#   Downloading dash-4.0.0-py3-none-any.whl.metadata (11 kB)
# Collecting dash-bootstrap-components (from upc-pymotion[viewer])
#   Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Collecting plotly (from upc-pymotion[viewer])
#   Downloading plotly-6.5.2-py3-none-any.whl.metadata (8.5 kB)
# Collecting Flask<3.2,>=1.0.4 (from dash->upc-pymotion[viewer])
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.2 (from dash->upc-pymotion[viewer])
#   Downloading werkzeug-3.1.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting importlib-metadata (from dash->upc-pymotion[viewer])
#   Downloading importlib_metadata-8.7.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from dash->upc-pymotion[viewer]) (4.15.0)
# Requirement already satisfied: requests in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from dash->upc-pymotion[viewer]) (2.32.5)
# Collecting retrying (from dash->upc-pymotion[viewer])
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from dash->upc-pymotion[viewer]) (1.6.0)
# Requirement already satisfied: setuptools in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from dash->upc-pymotion[viewer]) (81.0.0)
# Collecting blinker>=1.9.0 (from Flask<3.2,>=1.0.4->dash->upc-pymotion[viewer])
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from Flask<3.2,>=1.0.4->dash->upc-pymotion[viewer])
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<3.2,>=1.0.4->dash->upc-pymotion[viewer])
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from Flask<3.2,>=1.0.4->dash->upc-pymotion[viewer]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from Flask<3.2,>=1.0.4->dash->upc-pymotion[viewer]) (3.0.3)
# Requirement already satisfied: colorama in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash->upc-pymotion[viewer]) (0.4.6)
# Collecting narwhals>=1.15.1 (from plotly->upc-pymotion[viewer])
#   Downloading narwhals-2.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from plotly->upc-pymotion[viewer]) (26.0)
# Collecting zipp>=3.20 (from importlib-metadata->dash->upc-pymotion[viewer])
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from requests->dash->upc-pymotion[viewer]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from requests->dash->upc-pymotion[viewer]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from requests->dash->upc-pymotion[viewer]) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\jiabo\AppData\Roaming\Python\Python312\site-packages (from requests->dash->upc-pymotion[viewer]) (2026.1.4)
# Downloading dash-4.0.0-py3-none-any.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ---------------------------------------- 7.2/7.2 MB 64.1 MB/s  0:00:00
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading werkzeug-3.1.5-py3-none-any.whl (225 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading plotly-6.5.2-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 9.9/9.9 MB 68.3 MB/s  0:00:00
# Downloading narwhals-2.16.0-py3-none-any.whl (443 kB)
# Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
# Downloading importlib_metadata-8.7.1-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, Werkzeug, retrying, narwhals, itsdangerous, click, blinker, plotly, importlib-metadata, Flask, dash, dash-bootstrap-components
#
#    --- ------------------------------------  1/12 [Werkzeug]
#    --- ------------------------------------  1/12 [Werkzeug]
#    --- ------------------------------------  1/12 [Werkzeug]
#    --- ------------------------------------  1/12 [Werkzeug]
#    --- ------------------------------------  1/12 [Werkzeug]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------- -----------------------------  3/12 [narwhals]
#    ---------------- -----------------------  5/12 [click]
#    ---------------- -----------------------  5/12 [click]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    ----------------------- ----------------  7/12 [plotly]
#    -------------------------- -------------  8/12 [importlib-metadata]
#    ------------------------------ ---------  9/12 [Flask]
#    ------------------------------ ---------  9/12 [Flask]
#    ------------------------------ ---------  9/12 [Flask]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    --------------------------------- ------ 10/12 [dash]
#    ------------------------------------ --- 11/12 [dash-bootstrap-components]
#    ------------------------------------ --- 11/12 [dash-bootstrap-components]
#    ------------------------------------ --- 11/12 [dash-bootstrap-components]
#    ------------------------------------ --- 11/12 [dash-bootstrap-components]
#    ---------------------------------------- 12/12 [dash-bootstrap-components]
#
# Successfully installed Flask-3.1.2 Werkzeug-3.1.5 blinker-1.9.0 click-8.3.1 dash-4.0.0 dash-bootstrap-components-2.0.4 importlib-metadata-8.7.1 itsdangerous-2.2.0 narwhals-2.16.0 plotly-6.5.2 retrying-1.4.2 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script plotly_get_chrome.exe is installed in 'C:\Users\jiabo\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script flask.exe is installed in 'C:\Users\jiabo\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts dash-generate-components.exe, dash-update-components.exe, plotly.exe and renderer.exe are installed in 'C:\Users\jiabo\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
